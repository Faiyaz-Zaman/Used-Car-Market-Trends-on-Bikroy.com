# %%
import pandas as pd

# %%
df = pd.read_csv('secondhand_car_details.csv')
df.head()
# Out:
#     Brand                           Car Model Mileage Drove   City  \
# 0  Toyota          Toyota Premio F Grade 2012     59,000 km  Dhaka
# 1  Toyota      Toyota Fielder XG edition 2010     72,331 km  Dhaka
# 2  Toyota                Toyota Premio G 2004    135,000 km  Dhaka
# 3  Toyota           Toyota Corolla 80000 1998     80,000 km  Dhaka
# 4  Toyota  Toyota Aqua G Leather package 2014    115,000 km  Dhaka
#
#           Price Member How Long Ago
# 0  Tk 2,395,000     No    Not given
# 1  Tk 1,460,000     No    Not given
# 2  Tk 1,345,000     No    Not given
# 3    Tk 680,000     No    Not given
# 4  Tk 1,350,000     No    Not given

# %%
df.describe()
# Out:
#          Brand                      Car Model Mileage Drove        City  \
# count      450                            450           450         450
# unique      15                            408           173          11
# top     Toyota  Toyota Allion push start 2009     89,000 km  Chattogram
# freq       374                              5            40         223
#
#                Price Member How Long Ago
# count            450    450          450
# unique           232      2           20
# top     Tk 1,250,000    Yes       1 hour
# freq              12    359          160

# %%
df.isnull().sum()
# Out:
# Brand            0
# Car Model        0
# Mileage Drove    0
# City             0
# Price            0
# Member           0
# How Long Ago     0
# dtype: int64

# %%
df["Price"] = df["Price"].str.replace("Tk ", "").str.replace(",", "")

# Convert the Price column to numeric (optional)
df["Price (TK)"] = pd.to_numeric(df["Price"])

df.head()
# Out:
#     Brand                           Car Model Mileage Drove   City    Price  \
# 0  Toyota          Toyota Premio F Grade 2012     59,000 km  Dhaka  2395000
# 1  Toyota      Toyota Fielder XG edition 2010     72,331 km  Dhaka  1460000
# 2  Toyota                Toyota Premio G 2004    135,000 km  Dhaka  1345000
# 3  Toyota           Toyota Corolla 80000 1998     80,000 km  Dhaka   680000
# 4  Toyota  Toyota Aqua G Leather package 2014    115,000 km  Dhaka  1350000
#
#   Member How Long Ago  Price (TK)
# 0     No    Not given     2395000
# 1     No    Not given     1460000
# 2     No    Not given     1345000
# 3     No    Not given      680000
# 4     No    Not given     1350000

# %%
df = df.drop(columns=['Price'])

# %%
df.head()
# Out:
#     Brand                           Car Model Mileage Drove   City Member  \
# 0  Toyota          Toyota Premio F Grade 2012     59,000 km  Dhaka     No
# 1  Toyota      Toyota Fielder XG edition 2010     72,331 km  Dhaka     No
# 2  Toyota                Toyota Premio G 2004    135,000 km  Dhaka     No
# 3  Toyota           Toyota Corolla 80000 1998     80,000 km  Dhaka     No
# 4  Toyota  Toyota Aqua G Leather package 2014    115,000 km  Dhaka     No
#
#   How Long Ago  Price (TK)
# 0    Not given     2395000
# 1    Not given     1460000
# 2    Not given     1345000
# 3    Not given      680000
# 4    Not given     1350000

# %%
df["Mileage Drove (KM)"] = df["Mileage Drove"].str.replace(" km", "").str.replace(",", "").astype(int)



# Show the DataFrame with the cleaned columns
df.head()
# Out:
#     Brand                           Car Model Mileage Drove   City Member  \
# 0  Toyota          Toyota Premio F Grade 2012     59,000 km  Dhaka     No
# 1  Toyota      Toyota Fielder XG edition 2010     72,331 km  Dhaka     No
# 2  Toyota                Toyota Premio G 2004    135,000 km  Dhaka     No
# 3  Toyota           Toyota Corolla 80000 1998     80,000 km  Dhaka     No
# 4  Toyota  Toyota Aqua G Leather package 2014    115,000 km  Dhaka     No
#
#   How Long Ago  Price (TK)  Mileage Drove (KM)
# 0    Not given     2395000               59000
# 1    Not given     1460000               72331
# 2    Not given     1345000              135000
# 3    Not given      680000               80000
# 4    Not given     1350000              115000

# %%
df=df.drop(columns=["Mileage Drove"])

# %%
df["City"] = df["City"].replace({"Dhaka Division": "Dhaka","Rangpur Division": "Rangpur", "Chattogram Division": "Chittagong","Chattogram": "Chittagong","Rajshahi Division":"Rajshahi"})

# %%
df
# Out:
#         Brand                           Car Model        City Member  \
# 0      Toyota          Toyota Premio F Grade 2012       Dhaka     No
# 1      Toyota      Toyota Fielder XG edition 2010       Dhaka     No
# 2      Toyota                Toyota Premio G 2004       Dhaka     No
# 3      Toyota           Toyota Corolla 80000 1998       Dhaka     No
# 4      Toyota  Toyota Aqua G Leather package 2014       Dhaka     No
# ..        ...                                 ...         ...    ...
# 445  Mahindra          Mahindra TUV300 black 2020  Chittagong    Yes
# 446    Toyota           Toyota Premio silver 2005  Chittagong    Yes
# 447    Toyota       Toyota Premio push start 2015  Chittagong    Yes
# 448    Toyota      Toyota Esquire push start 2016  Chittagong    Yes
# 449    Toyota       Toyota Premio push start 2016  Chittagong    Yes
#
#     How Long Ago  Price (TK)  Mileage Drove (KM)
# 0      Not given     2395000               59000
# ...

# %%
df.to_csv("lastsecondhand_car_details.csv", index=False)

# %%
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
